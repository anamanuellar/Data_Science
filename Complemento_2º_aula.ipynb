# %% [markdown]
# <a href="https://colab.research.google.com/github/anamanuellar/Data_Science/blob/main/Complemento_2%C2%BA_aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
players = pd.read_csv('Players.csv')

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3922 entries, 0 to 3921
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3922 non-null   int64
#  1   Player       3921 non-null   object
#  2   height       3921 non-null   float64
#  3   weight       3921 non-null   float64
#  4   collage      3573 non-null   object
#  5   born         3921 non-null   float64
#  6   birth_city   3452 non-null   object
#  7   birth_state  3439 non-null   object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 245.2+ KB

# %%
players.head()
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
#
#                            collage    born   birth_city birth_state
# 0               Indiana University  1918.0          NaN         NaN
# 1           University of Kentucky  1921.0     Yorktown     Indiana
# 2         University of Notre Dame  1924.0          NaN         NaN
# 3  North Carolina State University  1925.0          NaN         NaN
# 4           University of Kentucky  1927.0  Hardinsburg    Kentucky

# %%
players.describe()
# Out:
#         Unnamed: 0       height       weight        born
# count  3922.000000  3921.000000  3921.000000  3921.00000
# mean   1960.500000   198.704922    94.783219  1962.37975
# std    1132.328206     9.269761    12.039515    20.33491
# min       0.000000   160.000000    60.000000  1913.00000
# 25%     980.250000   190.000000    86.000000  1948.00000
# 50%    1960.500000   198.000000    95.000000  1964.00000
# 75%    2940.750000   206.000000   102.000000  1979.00000
# max    3921.000000   231.000000   163.000000  1997.00000

# %%
players.height.mean()
# Out:
# 198.70492221372098

# %%
players.height.min()
# Out:
# 160.0

# %%
players.height.max()
# Out:
# 231.0

# %%
players.weight.min()
# Out:
# 60.0

# %%
players.weight.max()
# Out:
# 163.0

# %%
players.loc[players.height == players.height.max()] #Maior altura
# Out:
#       Unnamed: 0            Player  height  weight                   collage  \
# 1711        1711        Manute Bol   231.0    90.0  University of Bridgeport
# 2297        2297  Gheorghe Muresan   231.0   137.0                       NaN
#
#         born birth_city  birth_state
# 1711  1962.0    Gogrial  South Sudan
# 2297  1971.0    Triteni      Romania

# %%
players['birth_state'].value_counts()
# Out:
# California                          344
# New York                            290
# Illinois                            209
# Pennsylvania                        163
# Ohio                                137
#                                    ...
# Saint Vincent and the Grenadines      1
# Finland                               1
# Dominica                              1
# Norway                                1
# Austria                               1
# Name: birth_state, Length: 128, dtype: int64

# %%
players.query("(birth_state=='California') and (height<180.0)")
# Out:
#       Unnamed: 0        Player  height  weight  \
# 186          186  Fred Scolari   178.0    81.0
# 2397        2397    Tyus Edney   178.0    68.0
# 3676        3676   Casper Ware   178.0    79.0
#
#                                       collage    born     birth_city  \
# 186               University of San Francisco  1922.0  San Francisco
# 2397    University of California, Los Angeles  1973.0        Gardena
# 3676  California State University, Long Beach  1990.0       Cerritos
#
#      birth_state
# 186   California
# 2397  California
# 3676  California

# %%
#renomeando colunas
players.rename(columns={'Player':'Nome'}, inplace=True)
players.rename(columns={'height':'Altura'}, inplace=True)
players.rename(columns={'weight':'Peso'}, inplace=True)
players.rename(columns={'collage':'Universidade'}, inplace=True)
players.rename(columns={'born':'Nascido em'}, inplace=True)
players.rename(columns={'bith_city':'Cidade Natal'}, inplace=True)
players.rename(columns={'birth_state':'Estado Natal'}, inplace=True)
players
# Out:
#       Unnamed: 0               Nome  Altura   Peso  \
# 0              0    Curly Armstrong   180.0   77.0
# 1              1       Cliff Barker   188.0   83.0
# 2              2      Leo Barnhorst   193.0   86.0
# 3              3         Ed Bartels   196.0   88.0
# 4              4        Ralph Beard   178.0   79.0
# ...          ...                ...     ...    ...
# 3917        3917      Troy Williams   198.0   97.0
# 3918        3918       Kyle Wiltjer   208.0  108.0
# 3919        3919  Stephen Zimmerman   213.0  108.0
# 3920        3920        Paul Zipser   203.0   97.0
# 3921        3921        Ivica Zubac   216.0  120.0
#
#                          Universidade  Nascido em      birth_city  \
# 0                  Indiana University      1918.0             NaN
# 1              University of Kentucky      1921.0        Yorktown
# 2            University of Notre Dame      1924.0             NaN
# 3     North Carolina State University      1925.0             NaN
# ...

# %%
players.drop('Unnamed: 0', axis=1, inplace=True) #removendo a coluna 'Unnamed: 0'

# %%
players
# Out:
#                    Nome  Altura   Peso                     Universidade  \
# 0       Curly Armstrong   180.0   77.0               Indiana University
# 1          Cliff Barker   188.0   83.0           University of Kentucky
# 2         Leo Barnhorst   193.0   86.0         University of Notre Dame
# 3            Ed Bartels   196.0   88.0  North Carolina State University
# 4           Ralph Beard   178.0   79.0           University of Kentucky
# ...                 ...     ...    ...                              ...
# 3917      Troy Williams   198.0   97.0  South Carolina State University
# 3918       Kyle Wiltjer   208.0  108.0               Gonzaga University
# 3919  Stephen Zimmerman   213.0  108.0  University of Nevada, Las Vegas
# 3920        Paul Zipser   203.0   97.0                              NaN
# 3921        Ivica Zubac   216.0  120.0                              NaN
#
#       Nascido em      birth_city            Estado Natal
# ...

# %%
players.head(5).style.set_properties(**{'background-color': 'lightgreen'}, subset=['Nome','Universidade']) #colorindo coluna
# Out:
# <style type="text/css">
# #T_cab5f_row0_col0, #T_cab5f_row0_col3, #T_cab5f_row1_col0, #T_cab5f_row1_col3, #T_cab5f_row2_col0, #T_cab5f_row2_col3, #T_cab5f_row3_col0, #T_cab5f_row3_col3, #T_cab5f_row4_col0, #T_cab5f_row4_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cab5f_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Nome</th>
#       <th class="col_heading level0 col1" >Altura</th>
#       <th class="col_heading level0 col2" >Peso</th>
#       <th class="col_heading level0 col3" >Universidade</th>
#       <th class="col_heading level0 col4" >Nascido em</th>
#       <th class="col_heading level0 col5" >birth_city</th>
#       <th class="col_heading level0 col6" >Estado Natal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cab5f_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
titanic = pd.read_csv("Titanic.csv")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.sample(6)
# Out:
#      PassengerId  Survived  Pclass  \
# 700          701         1       1
# 280          281         0       3
# 487          488         0       1
# 270          271         0       1
# 422          423         0       3
# 617          618         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0      1
# 280                                   Duane, Mr. Frank    male  65.0      0
# 487                            Kent, Mr. Edward Austin    male  58.0      0
# 270                              Cairns, Mr. Alexander    male   NaN      0
# 422                                 Zimmerman, Mr. Leo    male  29.0      0
# 617    Lobb, Mrs. William Arthur (Cordelia K Stanlick)  female  26.0      1
#
#      Parch     Ticket     Fare    Cabin Embarked
# 700      0   PC 17757  227.525  C62 C64        C
# 280      0     336439    7.750      NaN        Q
# ...

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sobreviventes = titanic.query("(Survived ==1)")
sobreviventes.Survived.count() #Total sobreviventes
# Out:
# 342

# %%
criancas = titanic.query("(Age<=12.0)")
criancas
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 24            25         0       3             Palsson, Miss. Torborg Danira
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 827          828         1       2                     Mallet, Master. Andre
# 831          832         1       2           Richards, Master. George Sibley
# 850          851         0       3   Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                   Boulos, Miss. Nourelain
# 869          870         1       3           Johnson, Master. Harold Theodor
#
# ...

# %%
criancas.Embarked.count() #Total crianças menor que 12 anos embarcadas
# Out:
# 69

# %%
sobChild = criancas.query("(Survived == 0)") # Qtd de crianças que não sobreviveram
sobChild.Survived.count()
# Out:
# 29

# %%
titanic.loc[titanic.Age == titanic.Age.max()] #Mais velho
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  male  80.0      0      0  27042  30.0   A23        S

# %%
m22 = titanic.query("(Sex=='female') and (Age<22.0)") #Qtd mulheres com menos de 22 anos
m22.Sex.count()
# Out:
# 84

# %%
classe3 = titanic.query("(Pclass == 3)  and (Survived==0)") #Qtd não sobreviventes por classe
classe3.Survived.count()
# Out:
# 372

# %%
classe2 = titanic.query("(Pclass == 2)  and (Survived==0)") #Qtd não sobreviventes por classe
classe2.Survived.count()
# Out:
# 97

# %%
classe1 = titanic.query("(Pclass == 1)  and (Survived==0)") #Qtd não sobreviventes por classe
classe1.Survived.count()
# Out:
# 80

# %%
sobreviventes = titanic.query("(Survived == 0)") #classe com mais perda
sobreviventes.Pclass.value_counts().index[0]
# Out:
# 3

# %%
cher = titanic.query("(Embarked == 'C')") #Qtd passageiros embarcados em Cherboug
cher1 = titanic.query("(Embarked == 'S')") #Qtd passageiros embarcados em Southhampton
totalcher = cher.Embarked.count()
totalcher1 = cher1.Embarked.count()
conc = totalcher + totalcher1
conc
# Out:
# 812

# %%
mediaIdade = titanic.query("(')")classe.Age.mean() #idade média dos que não sobreviveram
# Out:
# 30.62617924528302

# %%
queenstowFare = titanic.query("(Fare > 0) and (Embarked == 'Q')")
queenstowFare
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 5              6         0       3                      Moran, Mr. James
# 16            17         0       3                  Rice, Master. Eugene
# 22            23         1       3           McGowan, Miss. Anna "Annie"
# 28            29         1       3         O'Dwyer, Miss. Ellen "Nellie"
# 32            33         1       3              Glynn, Miss. Mary Agatha
# ..           ...       ...     ...                                   ...
# 790          791         0       3              Keane, Mr. Andrew "Andy"
# 825          826         0       3                       Flynn, Mr. John
# 828          829         1       3          McCormack, Mr. Thomas Joseph
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
queenstowFare.Fare.sum() #Total tarifa arrecado em Queenstow
# Out:
# 1022.2543000000001

# %%
titanic.loc[titanic.Parch == titanic.Parch.max()] #Passageiro com mais membro da família a bordo
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 678          679         0       3  Goodwin, Mrs. Frederick (Augusta Tyler)
#
#         Sex   Age  SibSp  Parch   Ticket  Fare Cabin Embarked
# 678  female  43.0      1      6  CA 2144  46.9   NaN        S
