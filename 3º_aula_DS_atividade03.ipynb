# %% [markdown]
# <a href="https://colab.research.google.com/github/anamanuellar/Data_Science/blob/main/3%C2%BA_aula_DS_atividade03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
dfEmprestimo = pd.read_csv("previsao.csv") #1) Carregue para um DataFrame o Banco de Dados, 'previsao.csv' sobre previsão de Empréstimos.

# %%
dfEmprestimo.plot()

# %%
df3 = dfEmprestimo.groupby(dfEmprestimo.Gender).LoanAmount.sum()
df3.plot.bar()
